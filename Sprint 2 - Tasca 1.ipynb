# %% [markdown]
# # SPRINT 2 - TASCA 1

# %% [markdown]
# EJERCICIO 2:
#
# # Prueba de encabezado 1#
# ## Prueba de encabezado 2
# ### *Prueba de encabezado 3 y cursiva*

# %% [markdown]
# EJERCICIO 3:
#
# # Aquí vamos a probar a hacer una **lista** (atención a la *'negrita'*)
#
# 1. Primer **elemento**
# 2. Segundo elemento
# 3. tercer elemento
#
# # Segundo tipo de lista
# * Primer elemento
#   * Primer sub-elemento
#   * Segundo sub-elemento
# * Segundo elemento

# %% [markdown]
# EJERCICIO 3: AGREGAR FOTO
#
#
# ![fotoprueba.JPG](attachment:fotoprueba.JPG)

# %% [markdown]
# Ejemplo de Bloque de código: ```print('Hola, qué tal')```
